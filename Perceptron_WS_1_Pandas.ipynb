# %% [markdown]
# # Pandas Library
#
# By Kkrishna Saxena (Core Team Member MOSS)

# %% [markdown]
# ### What is Pandas ?
# Pandas is a python open source library that is widely used in the data science community to handle relational or labeled data both easily and intuitively in a tabular form. It has several useful features that make handling and preprocessing our data easier. This library is built on top of the NumPy library. It's fast and it has high performance & productivity for users.

# %% [markdown]
# ### Basics of Pandas
#
# The following line of code imports pandas and checks the pandas version

# %%
import pandas as pd
print(pd.__version__)

#pd is an alias for pandas and it just helps in writing less code everytime we call a method of pandas

# %% [markdown]
# The primary data structures in *pandas* are implemented as two classes:
#
#   * **`DataFrame`**
#   * **`Series`**

# %% [markdown]
# ## Introduction to Series
#
# ### What is a Series?
#
# * A Pandas Series is like a column in a table.
# * It is a one-dimensional array holding data of any type.

# %% [markdown]
# #### Seriers Data Representation
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Creating a Series

# %%
import pandas as pd
 
# Creating empty series
ser = pd.Series()
   
print(ser)
# Out:
# Series([], dtype: float64)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   after removing the cwd from sys.path.

# %%
# Creating a series from a list
data = ["M","O","S","S"]
ser = pd.Series(data)

print(ser)
# Out:
# 0    M
# 1    O
# 2    S
# 3    S
# dtype: object

# %%
# providing a name to the labels with help of index arguement
ser = pd.Series(data, index =["a","b","c","d"])
print(ser)
# Out:
# a    M
# b    O
# c    S
# d    S
# dtype: object

# %% [markdown]
# ### Accessing a Series
#
# There are two ways through which we can access element of series, they are :
#
# * Accessing Element from Series with Position
# * Accessing Element Using Label (index)

# %% [markdown]
# #### Accessing Element from Series with Position
#
# We use the index operator [ ] to access an element in a series. It must be an integer.
# In order to access multiple elements from a series, we use Slice operation.

# %%
 
# creating simple array
data = ["m","a","n","i","p","a","l"]
ser = pd.Series(data)

# retrieve the first element
print(ser[0])
# Out:
# m

# %%
#retrieve the first five elements
print(ser[:5])
# Out:
# 0    m
# 1    a
# 2    n
# 3    i
# 4    p
# dtype: object

# %%
print(ser)
# Out:
# 0    m
# 1    a
# 2    n
# 3    i
# 4    p
# 5    a
# 6    l
# dtype: object

# %%
#retrieve the last three elements
print(ser[-3:])
# Out:
# 4    p
# 5    a
# 6    l
# dtype: object

# %% [markdown]
# ####  Accessing Element Using Label (index)
#
# In order to access an element from series, we have to set values by index label. A Series is basically like a dictionary in which you can get and set values by index label.

# %%
# import pandas
import pandas as pd
 
# creating simple array
data = ["m","a","n","i","p","a","l"]
ser = pd.Series(data,index=[11,12,13,14,15,16,17])
print(ser)
# Out:
# 11    m
# 12    a
# 13    n
# 14    i
# 15    p
# 16    a
# 17    l
# dtype: object

# %%
# accessing a element using index element
print(ser[16])

# %%
# accessing a multiple element using index element
print(ser[[12,13,14]])
# Out:
# 12    a
# 13    n
# 14    i
# dtype: object

# %% [markdown]
# ## Introduction to Dataframes
#
# ### What is a DataFrame ?
#
# A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.
#
# Pandas DataFrame consists of three principal components:-
# * Data
# * Rows
# * Columns

# %% [markdown]
# #### Dataframe Table Representation
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Creating a DataFrame

# %% [markdown]
# #### Creating an empty dataframe
# The most basic DataFrame, that can be created is an Empty Dataframe. An Empty Dataframe can be created just by calling a dataframe constructor.

# %%
# import pandas as pd
import pandas as pd
 
# Calling DataFrame constructor
df = pd.DataFrame()
 
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Creating a dataframe using List
# DataFrame can also be created using a single list or a list of lists.

# %%
# import pandas as pd
import pandas as pd
 
# list of strings
lst = ["CSE","AIML","IT","DSE","CCE","ECE","EEE","MECH","CIVIL"]
 
# Calling DataFrame constructor on list
df = pd.DataFrame(lst)
print(df)
# Out:
#        0
# 0    CSE
# 1   AIML
# 2     IT
# 3    DSE
# 4    CCE
# 5    ECE
# 6    EEE
# 7   MECH
# 8  CIVIL

# %% [markdown]
# #### Creating DataFrame from dict of ndarray/lists
# To create DataFrame from dict of narray/list, all the narray must be of same length. If index is passed then the length index should be equal to the length of arrays. If no index is passed, then by default, index will be range(n) where n is the array length.

# %%
# Creating DataFrame from dict narray / lists By default addresses.
 
import pandas as pd
 
# initialise data of lists.
data = {'Name':["Aman", "Rohan", "Mohan","Pranav"], 'Age':[20, 21, 19, 18]}
 
# Create DataFrame
df = pd.DataFrame(data)
 
# Print the output.
print(df)
# Out:
#      Name  Age
# 0    Aman   20
# 1   Rohan   21
# 2   Mohan   19
# 3  Pranav   18

# %% [markdown]
# #### Create pandas dataframe from lists using dictionary:
# We can create pandas dataframe from lists using dictionary using pd.DataFrame(). With this method in Pandas we can transform a dictionary of list to a dataframe.

# %%
import pandas as pd

#dictionary of lists
data = {
  "name": ["Aman", "Rohan", "Mohan","Pranav"],
  "Age":[20, 21, 19, 18],
  "branch": ["CSE","CCE","EEE","MECH"],
  "section": ["A","E","K","M"],
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#      name  Age branch section
# 0    Aman   20    CSE       A
# 1   Rohan   21    CCE       E
# 2   Mohan   19    EEE       K
# 3  Pranav   18   MECH       M

# %% [markdown]
# ### Locating a Row
# As you can see from the result above, DataFrames are like a table with rows and columns.
#
# Pandas use the `loc` attribute to return one or more specified row(s)

# %%
#refer to the row index:
print(df.loc[0])
type(df.loc[0])

# Note: This example returns a Series.
# Out:
# name       Aman
# Age          20
# branch      CSE
# section       A
# Name: 0, dtype: object
# pandas.core.series.Series

# %%
#use a list of indexes:
print(df.loc[[0, 1]])

# Note: When using [], the result is a Pandas DataFrame.
# Out:
#     name  Age branch section
# 0   Aman   20    CSE       A
# 1  Rohan   21    CCE       E

# %% [markdown]
# ### Accessing Rows

# %% [markdown]
# ### Accessing Columns

# %% [markdown]
# ### Named Indexes
# With the index argument, you can name your own indexes.

# %% [markdown]
# #### Naming your own indexes
# Add a list of names to give each row a name:

# %%
import pandas as pd

data = {
  "name": ["Aman", "Rohan", "Mohan","Pranav"],
  "branch": ["CSE","CCE","EEE","MECH"],
  "section": ["A","E","K","M"],
}

#listing the named indexes
df = pd.DataFrame(data,index=["Student1","Student2","Student3","Student4"])

print(df)
# Out:
#             name branch section
# Student1    Aman    CSE       A
# Student2   Rohan    CCE       E
# Student3   Mohan    EEE       K
# Student4  Pranav   MECH       M

# %% [markdown]
# #### Locating Named Indexes
# Use the named index in the `loc` attribute to return the specified row(s).

# %%
#refer to the named index:
print(df.loc["Student1"])
# Out:
# name       Aman
# branch      CSE
# section       A
# Name: Student1, dtype: object

# %%
#Accessing Columns 
print(df["name"])
# Out:
# Student1      Aman
# Student2     Rohan
# Student3     Mohan
# Student4    Pranav
# Name: name, dtype: object

# %% [markdown]
# ### Handling Missing Data in Pandas
# Missing Data can occur when no information is provided for one or more items or for a whole unit. Missing Data is a very big problem in a real-life scenarios. Missing Data can also refer to as NA (Not Available) values in pandas. In DataFrame sometimes many datasets simply arrive with missing data, either because it exists and was not collected or it never existed.
#
# For Example, Suppose different fourth year students being surveyed may choose not to share their CGPA, some users may choose not to share the placement package in this way many datasets went missing.

# %% [markdown]
# In Pandas missing data is represented by two value:
#
# * None: None is a Python singleton object that is often used for missing data in Python code.
# * NaN : NaN (an acronym for Not a Number)

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'A':[1,2,np.nan],
                  'B':[5,np.nan,np.nan],
                  'C':[1,2,3]})
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %% [markdown]
# Pandas treat None and NaN as essentially interchangeable for indicating missing or null values. To facilitate this convention, there are several useful functions for detecting, removing, and replacing null values in Pandas DataFrame :
#
# * isnull()
# * notnull()
# * dropna()
# * fillna()
# * replace()
# * interpolate()

# %% [markdown]
# ##### Checking for missing values using isnull()
# In order to check null values in Pandas DataFrame, we use isnull() function this function return dataframe of Boolean values which are True for NaN values.

# %%
import pandas as pd
import numpy as np
  
# dictionary of lists
dict = {'First Sem':[74, 90, np.nan, 95,80],
        'Second Sem': [80, 75, 76, np.nan,82],
        'Third Sem':[83,np.nan, 73, 80, 88]}
      
  
# creating a dataframe from list
df = pd.DataFrame(dict)
print(df)
  
# using isnull() function  
df.isnull()
# Out:
#    First Sem  Second Sem  Third Sem
# 0       74.0        80.0       83.0
# 1       90.0        75.0        NaN
# 2        NaN        76.0       73.0
# 3       95.0         NaN       80.0
# 4       80.0        82.0       88.0
#    First Sem  Second Sem  Third Sem
# 0        NaN         NaN        NaN
# 1        NaN         NaN        NaN
# 2        NaN         NaN        NaN
# 3        NaN         NaN        NaN
# 4        NaN         NaN        NaN

# %% [markdown]
# #### Checking for missing values using notnull()
# In order to check null values in Pandas Dataframe, we use notnull() function this function return dataframe of Boolean values which are False for NaN values.
#
# It's the exact opposite of isnull()

# %%
# using notnull() function 
df.notnull()
# Out:
#    First Sem  Second Sem  Third Sem
# 0       True        True       True
# 1       True        True      False
# 2      False        True       True
# 3       True       False       True
# 4       True        True       True

# %% [markdown]
# #### Dropping missing values using dropna()
# In order to drop a null values from a dataframe, we used dropna() function this function drop Rows/Columns of datasets with Null values in different ways.

# %%
df.dropna()
# Out:
#    First Sem  Second Sem  Third Sem
# 0       74.0        80.0       83.0
# 4       80.0        82.0       88.0

# %% [markdown]
# #### Filling missing values using fillna()

# %%
df.fillna(0)
# Out:
#    First Sem  Second Sem  Third Sem
# 0       74.0        80.0       83.0
# 1       90.0        75.0        0.0
# 2        0.0        76.0       73.0
# 3       95.0         0.0       80.0
# 4       80.0        82.0       88.0

# %% [markdown]
# #### Filling a null values using replace()

# %%
df.replace(to_replace = np.nan, value = 0)

# %% [markdown]
# #### Filling the missing values by interpolating them
# Let’s interpolate the missing values using Linear method. Note that Linear method ignore the index and treat the values as equally spaced.

# %%
df.interpolate(method ='linear', limit_direction ='forward')
# Out:
#    First Sem  Second Sem  Third Sem
# 0       74.0        80.0       83.0
# 1       90.0        75.0       78.0
# 2       92.5        76.0       73.0
# 3       95.0        79.0       80.0
# 4       80.0        82.0       88.0

# %% [markdown]
# ### Group By
# Pandas groupby is used for grouping the data according to the categories and apply a function to the categories. It also helps to aggregate data efficiently.
#
# Pandas `dataframe.groupby()` function is used to split the data into groups based on some criteria. pandas objects can be split on any of their axes.

# %% [markdown]
# Use `groupby()` function to group the data based on the Survived on TITANIC

# %%
import pandas as pd

data = "https://raw.githubusercontent.com/kkrishna007/Perceptron_Pandas/main/nba.csv"
df = pd.read_csv(data)

# applying groupby() function to group the data on survived value
team=df.groupby('Team')

# Let's print the first entries in all the groups formed.
team.first()
# Out:
#                                          Name  Number Position   Age Height  \
# Team
# Atlanta Hawks                   Kent Bazemore    24.0       SF  26.0    6-5
# Boston Celtics                  Avery Bradley     0.0       PG  25.0    6-2
# Brooklyn Nets                Bojan Bogdanovic    44.0       SG  27.0    6-8
# Charlotte Hornets               Nicolas Batum     5.0       SG  27.0    6-8
# Chicago Bulls                Cameron Bairstow    41.0       PF  25.0    6-9
# Cleveland Cavaliers       Matthew Dellavedova     8.0       PG  25.0    6-4
# Dallas Mavericks              Justin Anderson     1.0       SG  22.0    6-6
# Denver Nuggets                 Darrell Arthur     0.0       PF  28.0    6-9
# Detroit Pistons                  Joel Anthony    50.0        C  33.0    6-9
# Golden State Warriors         Leandro Barbosa    19.0       SG  33.0    6-3
# Houston Rockets                  Trevor Ariza     1.0       SF  30.0    6-8
# ...

# %% [markdown]
# Let’s print the value contained any one of group. For that use the name of the team. We use the function `get_group()` to find the entries contained in any of the groups.

# %%
# Finding the values contained in the "Atlanta Hawks" group
team.get_group('Atlanta Hawks')
# Out:
#                  Name           Team  Number Position   Age Height  Weight  \
# 309     Kent Bazemore  Atlanta Hawks    24.0       SF  26.0    6-5   201.0
# 310  Tim Hardaway Jr.  Atlanta Hawks    10.0       SG  24.0    6-6   205.0
# 311      Kirk Hinrich  Atlanta Hawks    12.0       SG  35.0    6-4   190.0
# 312        Al Horford  Atlanta Hawks    15.0        C  30.0   6-10   245.0
# 313    Kris Humphries  Atlanta Hawks    43.0       PF  31.0    6-9   235.0
# 314       Kyle Korver  Atlanta Hawks    26.0       SG  35.0    6-7   212.0
# 315      Paul Millsap  Atlanta Hawks     4.0       PF  31.0    6-8   246.0
# 316      Mike Muscala  Atlanta Hawks    31.0       PF  24.0   6-11   240.0
# 317   Lamar Patterson  Atlanta Hawks    13.0       SG  24.0    6-5   225.0
# 318   Dennis Schroder  Atlanta Hawks    17.0       PG  22.0    6-1   172.0
# 319        Mike Scott  Atlanta Hawks    32.0       PF  27.0    6-8   237.0
# ...

# %% [markdown]
# Use groupby() function to form groups based on more than one category
#
# (i.e. Use more than one column to perform the splitting).

# %%
# First grouping based on "Team" Within each team we are grouping based on "Position"
team_pos = df.groupby(['Team', 'Position'])
  
# Print the first value in each group
team_pos.first()
# Out:
#                                          Name  Number   Age Height  Weight  \
# Team               Position
# Atlanta Hawks      C               Al Horford    15.0  30.0   6-10   245.0
#                    PF          Kris Humphries    43.0  31.0    6-9   235.0
#                    PG         Dennis Schroder    17.0  22.0    6-1   172.0
#                    SF           Kent Bazemore    24.0  26.0    6-5   201.0
#                    SG        Tim Hardaway Jr.    10.0  24.0    6-6   205.0
# ...                                       ...     ...   ...    ...     ...
# Washington Wizards C            Marcin Gortat    13.0  32.0   6-11   240.0
#                    PF             Drew Gooden    90.0  34.0   6-10   250.0
#                    PG          Ramon Sessions     7.0  30.0    6-3   190.0
#                    SF            Jared Dudley     1.0  30.0    6-7   225.0
#                    SG           Alan Anderson     6.0  33.0    6-6   220.0
#
# ...

# %% [markdown]
# #### Aggregate methods in groupby()

# %% [markdown]
# Mean of groups

# %%
df.groupby('Age').mean()
# Out:
#          Number      Weight        Salary
# Age
# 19.0  10.500000  204.000000  1.930440e+06
# 20.0  17.210526  223.736842  2.725791e+06
# 21.0  18.315789  220.894737  2.067380e+06
# 22.0  14.423077  224.230769  2.357963e+06
# 23.0  19.682927  214.048780  2.034746e+06
# 24.0  16.468085  216.744681  3.785300e+06
# 25.0  19.866667  214.333333  3.930867e+06
# 26.0  17.277778  228.500000  6.866566e+06
# 27.0  18.682927  220.463415  6.676741e+06
# 28.0  19.741935  222.967742  5.110189e+06
# 29.0  16.892857  233.321429  6.224177e+06
# 30.0  12.032258  214.645161  7.061859e+06
# 31.0  12.681818  229.772727  8.511397e+06
# 32.0  12.846154  220.846154  7.716958e+06
# 33.0  23.571429  226.357143  3.930739e+06
# 34.0  23.500000  227.300000  7.606030e+06
# 35.0  19.666667  229.222222  3.461740e+06
# 36.0  19.700000  222.100000  2.238120e+06
# 37.0  28.500000  239.000000  1.277778e+07
# 38.0  24.500000  218.750000  1.840041e+06
# 39.0  12.000000  202.500000  2.517872e+06
# ...

# %% [markdown]
# Median of groups

# %%
df.groupby('Age').median()
# Out:
#       Number  Weight     Salary
# Age
# 19.0    10.5   204.0  1930440.0
# 20.0    13.0   220.0  2481720.0
# 21.0    17.0   218.0  1584480.0
# 22.0    12.0   229.0  1793880.0
# 23.0    13.0   206.0  1175880.0
# 24.0    12.0   214.0  1509360.0
# 25.0    15.0   215.0  1305660.0
# 26.0    14.5   227.0  3325000.0
# 27.0    12.0   220.0  3425510.0
# 28.0    14.0   220.0  4194803.5
# 29.0    12.0   233.0  5543725.0
# 30.0     9.0   210.0  5867803.0
# 31.0     8.5   237.5  5439487.0
# 32.0     9.0   220.0  5200000.0
# 33.0    18.5   230.0  2300000.0
# 34.0     9.0   230.0  6280675.5
# 35.0    24.0   230.0  3302470.0
# 36.0    18.5   227.0  1809826.0
# 37.0    32.5   245.0  8333334.0
# 38.0    25.5   220.0  1880638.0
# 39.0    12.0   202.5  2517872.5
# 40.0    21.0   240.0  5250000.0

# %% [markdown]
# Standard Deviation of Groups

# %%
df.groupby('Age').std()
# Out:
#          Number     Weight        Salary
# Age
# 19.0  13.435029   2.828427  2.791658e+05
# 20.0  14.199292  22.280640  1.510913e+06
# 21.0  12.614157  25.514472  1.412350e+06
# 22.0  12.551249  25.451613  1.517378e+06
# 23.0  19.517222  25.264551  2.728292e+06
# 24.0  14.887770  25.617986  4.803384e+06
# 25.0  18.501351  25.033614  4.558463e+06
# 26.0  13.081309  24.702227  6.100471e+06
# 27.0  16.879631  29.021628  6.831984e+06
# 28.0  17.826886  26.904131  4.316627e+06
# 29.0  18.736653  22.575066  4.870706e+06
# 30.0  11.827888  28.191664  5.408670e+06
# 31.0  13.047117  32.790724  7.170163e+06
# 32.0   9.906615  27.193278  7.451336e+06
# 33.0  17.212314  27.553046  4.354293e+06
# 34.0  29.014364  29.563679  5.653035e+06
# 35.0  11.958261  20.980811  2.364690e+06
# 36.0  13.047350  24.727178  1.550061e+06
# 37.0  16.542874  18.493242  1.071517e+07
# 38.0   9.746794  29.261750  1.496661e+06
# 39.0   4.242641  24.748737  2.220522e+06
# 40.0   1.732051  26.457513  4.155421e+06

# %% [markdown]
# Minimum and Maximum of groups

# %%
df.groupby('Salary').min()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   """Entry point for launching an IPython kernel.
#                               Name                  Team  Number Position  \
# Salary
# 30888.0     Thanasis Antetokounmpo       New York Knicks    43.0       SF
# 55722.0            Orlando Johnson  New Orleans Pelicans     0.0       PG
# 83397.0              Alan Williams          Phoenix Suns    15.0        C
# 111196.0              Jordan McRae   Cleveland Cavaliers    12.0       SG
# 111444.0                Jeff Ayres       Detroit Pistons    17.0       PF
# ...                            ...                   ...     ...      ...
# 22192730.0              Chris Bosh            Miami Heat     1.0       PF
# ...

# %%
df.groupby('Salary').max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   """Entry point for launching an IPython kernel.
#                               Name                  Team  Number Position  \
# Salary
# 30888.0     Thanasis Antetokounmpo       New York Knicks    43.0       SF
# 55722.0               Phil Pressey          Phoenix Suns    25.0       SG
# 83397.0              Alan Williams          Phoenix Suns    15.0        C
# 111196.0              Jordan McRae   Cleveland Cavaliers    12.0       SG
# 111444.0             Lorenzo Brown  Los Angeles Clippers    19.0       PG
# ...                            ...                   ...     ...      ...
# 22192730.0              Chris Bosh            Miami Heat     1.0       PF
# ...

# %% [markdown]
# ### Operations

# %% [markdown]
# ### Merging, Joining, and Concatenating
# There are 3 main ways of combining DataFrames together:
# * Merging
# * Joining
# * Concatenating.

# %% [markdown]
# #### Concatenation
#
# Concatenation basically glues together DataFrames. Keep in mind that dimensions should match along the axis you are concatenating on. You can use `pd.concat` and pass in a list of DataFrames to concatenate together:

# %%
import pandas as pd

df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7]) 

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# #### Merging
#
# The `merge` function allows you to merge DataFrames together using a similar logic as merging SQL Tables together. For example:

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
pd.merge(left,right,how='inner',on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %% [markdown]
# #### Joining
# Joining is a convenient method for combining the columns of two potentially differently-indexed DataFrames into a single result DataFrame.

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
left.join(right)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %% [markdown]
# ### Read/Write Tabular Data in Pandas
# ![ReadWrite](https://drive.google.com/uc?export=view&id=1PqwknPA02NATebN2lD9RAqUoBzFzLzUW)

# %% [markdown]
# #### Reading CSV Files
# A simple way to store big data sets is to use CSV files (comma separated files).
#
# CSV files contains plain text and is a well know format that can be read by everyone including Pandas.

# %%
import pandas as pd

data = "https://raw.githubusercontent.com/kkrishna007/Perceptron_Pandas/main/titanic.csv"
df = pd.read_csv(data)

df.head()
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# If you have a large DataFrame with many rows, Pandas will only return the first 5 rows, and the last 5 rows
#
# We use to_string() to print the entire DataFrame.

# %%
print(df.to_string())

# %% [markdown]
# #### Reading JSON Files
# Big data sets are often stored, or extracted as JSON.
#
# JSON is plain text, but has the format of an object, and is well known in the world of programming, including Pandas.

# %%
import pandas as pd

data="https://raw.githubusercontent.com/kkrishna007/Perceptron_Pandas/main/titanic.json"
df = pd.read_json(data)

print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38      1
# 2                               Heikkinen, Miss. Laina  female  26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35      1
# 4                             Allen, Mr. William Henry    male  35      0
# ..                                                 ...     ...  ..    ...
# ...

# %%
#to print the entire dataframe
print(df.to_string())
# Out:
#      PassengerId  Survived  Pclass                                                                                Name     Sex   Age  SibSp  Parch              Ticket      Fare            Cabin Embarked
# 0              1         0       3                                                             Braund, Mr. Owen Harris    male    22      1      0           A/5 21171    7.2500                         S
# 1              2         1       1                                 Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female    38      1      0            PC 17599   71.2833              C85        C
# 2              3         1       3                                                              Heikkinen, Miss. Laina  female    26      0      0    STON/O2. 3101282    7.9250                         S
# ...

# %% [markdown]
# #### Reading XLSX Files
# An XLSX file is a Microsoft Excel Open XML Format Spreadsheet file which is widely used in professional workspaces.

# %%
import pandas as pd

file =('titanic.xlsx')
df = pd.read_excel(file)
print (df)

# %%
#to print the entire dataframe
print(df.to_string())
# Out:
#      PassengerId  Survived  Pclass                                                                                Name     Sex   Age  SibSp  Parch              Ticket      Fare            Cabin Embarked
# 0              1         0       3                                                             Braund, Mr. Owen Harris    male    22      1      0           A/5 21171    7.2500                         S
# 1              2         1       1                                 Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female    38      1      0            PC 17599   71.2833              C85        C
# 2              3         1       3                                                              Heikkinen, Miss. Laina  female    26      0      0    STON/O2. 3101282    7.9250                         S
# ...

# %% [markdown]
# #### Reading HTML Files
# For the first example, we will try to parse this table of Cricket World Cup History from wikipedia.

# %%
import pandas as pd

table_WC = pd.read_html("https://en.wikipedia.org/wiki/List_of_Cricket_World_Cup_finals",match="ICC World Cup")
table_WC[0]
# Out:
#     Year       Winner           Winner's score      Winningmargin  \
# 0   1975  West Indies         291/8 (60 overs)        17 runs[11]
# 1   1979  West Indies         286/9 (60 overs)        92 runs[16]
# 2   1983        India  183 all out (55th over)        43 runs[20]
# 3   1987    Australia         253/5 (50 overs)         7 runs[21]
# 4   1992     Pakistan         249/6 (50 overs)        22 runs[23]
# 5   1996    Sri Lanka       245/3 (46.2 overs)      7 wickets[25]
# 6   1999    Australia       133/2 (20.1 overs)      8 wickets[28]
# 7   2003    Australia         359/2 (50 overs)       125 runs[30]
# 8   2007    Australia         281/4 (38 overs)       53 runs [32]
# 9   2011        India       277/4 (48.2 overs)      6 wickets[35]
# 10  2015    Australia       186/3 (33.1 overs)      7 wickets[36]
# 11  2019      England   241 all out (50 overs)  Tiebreak: 9 fours
#
#       Runner-up              R/Up's score                Final venue  \
# ...

# %% [markdown]
# # Well Done !!!
# Made by : Kkrishna Saxena (Core Team Member MOSS)
